# %%
a = [1, 2, 3]
print(a * 2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
a = [1, 2, 3]
print(a + [4, 5])
# Out:
# [1, 2, 3, 4, 5]

# %%
a = [1, 2, 3]
a[1] = [9, 9]
print(a)
# Out:
# [1, [9, 9], 3]

# %%
a = {"x": 1}
print(a.get("y", 0))
# Out:
# 0

# %%
a = {"x": 1}
a["x"] = 5
print(a)
# Out:
# {'x': 5}

# %%
a = {"x": 1}
b = a
b["y"] = 2
print(a)
# Out:
# {'x': 1, 'y': 2}

# %%
a = [[]] * 3
a[0].append(1)
print(a)
# Out:
# [[1], [1], [1]]

# %%
a = {"x": 1, "x": 2, "x": 3}
print(a)
# Out:
# {'x': 3}

# %%
print(True + True * 2)
# Out:
# 3

# %%
a = ""
if a:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
a = "abcdef"
print(a[3:1:-1])
# Out:
# dc

# %%
print([1, 2] < [2, 1])
# Out:
# True

# %%
a = {True, 1, False, 0}
print(a)
# Out:
# {False, True}

# %%
a = [1, 2, 3]
print(a[10:])
# Out:
# []

# %%
print([] == False)
# Out:
# False
